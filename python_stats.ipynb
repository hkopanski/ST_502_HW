# %%
import math
import seaborn as sns
import pandas as pd

n = 50
p = 0.5
k = list(range(0,51))

for i in k:
    print(math.comb(n, i)*(p**i)*(1-p)**(n - i))
# Out:
# 8.881784197001252e-16
# 4.440892098500626e-14
# 1.0880185641326534e-12
# 1.7408297026122455e-11
# 2.0454749005693884e-10
# 1.8818369085238373e-09
# 1.411377681392878e-08
# 8.871516854469519e-08
# 4.768440309277366e-07
# 2.2252721443294377e-06
# 9.123615791750694e-06
# 3.317678469727525e-05
# 0.00010782455026614457
# 0.0003151794546241149
# 0.0008329742729351608
# 0.001999138255044386
# 0.004373114932909594
# 0.008746229865819188
# 0.016034754754001845
# 0.027005902743582055
# 0.041859149252552186
# 0.05979878464650312
# 0.07882567067039048
# 0.09596168603351884
# 0.1079568967877087
# 0.11227517265921705
# 0.1079568967877087
# 0.09596168603351884
# 0.07882567067039048
# 0.05979878464650312
# 0.041859149252552186
# 0.027005902743582055
# 0.016034754754001845
# 0.008746229865819188
# 0.004373114932909594
# 0.001999138255044386
# 0.0008329742729351608
# 0.0003151794546241149
# 0.00010782455026614457
# 3.317678469727525e-05
# 9.123615791750694e-06
# 2.2252721443294377e-06
# ...
